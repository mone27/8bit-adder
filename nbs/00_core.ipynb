# %% [markdown]
# # RPi Server
# > API server running on the raspberry to control the adder inputs

# %%
#| default_exp core

# %%
import RPi.GPIO as GPIO
GPIO.setmode(GPIO.BCM) # numbers from 0 to 40

# %% [markdown]
# pinout of a RPI
# ![image.png](attachment:ec444d8b-4b9a-410a-b92b-1ba80388f384.png)

# %%
pins_a = [7, 11, 13, 15, 19, 21, 23, 27] # high to low
pins_a.reverse()

# %%
pins_a
# Out:
# [27, 23, 21, 19, 15, 13, 11, 7]

# %%
GPIO.setup(pins_a, GPIO.OUT)

# %%
GPIO.output(pins_a, GPIO.HIGH)

# %%
#| hide
import nbdev; nbdev.nbdev_export()

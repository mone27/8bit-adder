# %%
#| hide
from 8bit_adder.core import *

# %% [markdown]
# # 8bit-adder
#
# > A debugger for a 8bit adder board

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install 8bit_adder in Development mode

# %% [markdown]
# ```sh
# # make sure 8bit_adder package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to 8bit_adder
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/mone27/8bit-adder.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c mone27 8bit_adder
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install 8bit_adder
# ```
#
#
# [repo]: https://github.com/mone27/8bit-adder
# [docs]: https://mone27.github.io/8bit-adder/
# [pypi]: https://pypi.org/project/8bit-adder/
# [conda]: https://anaconda.org/mone27/8bit-adder

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/mone27/8bit-adder
# [docs]: https://mone27.github.io/8bit-adder/
# [pypi]: https://pypi.org/project/8bit-adder/
# [conda]: https://anaconda.org/mone27/8bit-adder

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
